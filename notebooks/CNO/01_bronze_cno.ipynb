# %% [markdown]
# ## DTO dados cadastro nacional de obras

# %% [markdown]
# ###Criação da tabela CNO

# %%
import sys
sys.path.append("/Workspace/mvp-engenharia-dados/src")

from data_pipeline import (
    read_csv,
    normalizar_colunas,
    save_table,
    add_column_comments
)

df = read_csv(spark, "/Volumes/workspace/cno/raw/cno.csv")
df = normalizar_colunas(df)

save_table(df," bronze.cno")

# %% [markdown]
# ### Inclusão de comentários CNO
# Enriquencimento de metadados

# %%
from metadata import CNO_COMMENTS

add_column_comments(
    spark,
    "bronze.cno",
    CNO_COMMENTS
)
